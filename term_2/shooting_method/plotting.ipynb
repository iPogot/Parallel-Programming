# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
without_correction_data = pd.read_csv('res_without_correction.csv').values
res_correct_data = pd.read_csv('res_corrects.csv').values

# %%
preshot_t = without_correction_data[: , 0]
preshot_y = without_correction_data[: , 1]

# %%
shot_t = res_correct_data[: , 0]
shot_y = res_correct_data[: , 1]

# %%
fig = plt.figure(figsize=(8, 8))
axes = fig.add_axes([0, 0, 1, 1])
plt.plot(preshot_t, preshot_y)
plt.plot(shot_t, shot_y)
